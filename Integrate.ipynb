# %%
from package.function import *

# 生成 視覺化預測結果 對比圖
for modeltype in ['DeepLab','FCN','SegNet','UNet','UNetPlusPlus']:#
    for fold in range(1,6):
        create_comparison_image(fold,modeltype)
# Out:
# Saved: ETT_compared/DeepLab/Fold1\0.png
# Saved: ETT_compared/DeepLab/Fold1\1.png
# Saved: ETT_compared/DeepLab/Fold1\2.png
# Saved: ETT_compared/DeepLab/Fold1\3.png
# Saved: ETT_compared/DeepLab/Fold1\4.png
# Saved: ETT_compared/DeepLab/Fold1\5.png
# Saved: ETT_compared/DeepLab/Fold1\6.png
# Saved: ETT_compared/DeepLab/Fold1\7.png
# Saved: ETT_compared/DeepLab/Fold1\8.png
# Saved: ETT_compared/DeepLab/Fold1\9.png
# Saved: ETT_compared/DeepLab/Fold1\10.png
# Saved: ETT_compared/DeepLab/Fold1\11.png
# Saved: ETT_compared/DeepLab/Fold1\12.png
# Saved: ETT_compared/DeepLab/Fold1\13.png
# Saved: ETT_compared/DeepLab/Fold1\14.png
# Saved: ETT_compared/DeepLab/Fold1\15.png
# Saved: ETT_compared/DeepLab/Fold1\16.png
# Saved: ETT_compared/DeepLab/Fold1\17.png
# Saved: ETT_compared/DeepLab/Fold1\18.png
# Saved: ETT_compared/DeepLab/Fold1\19.png
# Saved: ETT_compared/DeepLab/Fold1\20.png
# Saved: ETT_compared/DeepLab/Fold1\21.png
# Saved: ETT_compared/DeepLab/Fold1\22.png
# ...
